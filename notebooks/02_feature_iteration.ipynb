# %% [markdown]
# # 02 — Feature iteration
#
# Toggle composition / physics / processing buckets in `FeatureMatrixBuilder` and compare offline CV metrics via `scripts/train.py`.

# %%
# Example: from nanocomposite_hardness.pipeline.feature_matrix import FeatureMatrixBuilder
# import pandas as pd
# df = pd.read_parquet("../data/interim/canonical.parquet")
# X, names = FeatureMatrixBuilder(use_composition=True, use_physics=True, use_processing=True).fit(df).transform(df)
# X.shape, len(names)
