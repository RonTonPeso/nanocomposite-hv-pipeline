# %% [markdown]
# # 03 — SHAP analysis
#
# After `scripts/train.py`, open `artifacts/shap_summary_bar.png` or rebuild explanations from `artifacts/screening_bundle.joblib`.

# %%
from pathlib import Path
import joblib
import pandas as pd

bundle = joblib.load(Path("../artifacts/screening_bundle.joblib"))
len(bundle["models"]), bundle["feature_names"][:5]
